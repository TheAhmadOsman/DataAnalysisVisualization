# %%
# Ahmad M. Osman - DS320
import urllib
import ssl
from bs4 import BeautifulSoup

# Reading the front page HTML
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# Read the HTML from the URL and pass on to BeautifulSoup
url = 'https://www.cia.gov/library/publications/the-world-factbook/'
print("Opening the file connection...")
uh= urllib.request.urlopen(url, context=ctx)
print("HTTP status",uh.getcode())
html = uh.read().decode()
print("Reading done. Total {} characters read.".format(len(html)))

soup = BeautifulSoup(html, 'html.parser')
country_codes=[]
country_names=[]

# Find the HTML tags named ‘option’
for tag in soup.find_all('option'):
    # The char 5 and 6 of the tag value represent the 2-character country code.
    country_codes.append(tag.get('value')[5:7])
    country_names.append(tag.text)
temp=country_codes.pop(0) # To remove the first entry 'World'
temp=country_names.pop(0) # To remove the first entry 'World'

# Download all the text data of all countries into a dictionary by scraping each page individually
# The key thing to identify is how the URL of each countries information page is structured

# Base URL
urlbase = 'https://www.cia.gov/library/publications/the-world-factbook/geos/'
# Empty data dictionary
text_data=dict()
# Iterate over every country
for i in range(1,len(country_names)-1):
    country_html=country_codes[i]+'.html'
    url_to_get=urlbase+country_html
    # Read the HTML from the URL and pass on to BeautifulSoup
    html = urllib.request.urlopen(url_to_get, context=ctx).read()
    soup = BeautifulSoup(html, 'html.parser')
    txt=soup.get_text()
    text_data[country_names[i]]=txt
    print("Finished loading data for {}".format(country_names[i]))
    
print ("\n**Finished downloading all text data!**")
# Out:
# Opening the file connection...
# HTTP status 200
# Reading done. Total 75080 characters read.
# Finished loading data for  Afghanistan
# Finished loading data for  Akrotiri
# Finished loading data for  Albania
# Finished loading data for  Algeria
# Finished loading data for  American Samoa
# Finished loading data for  Andorra
# Finished loading data for  Angola
# Finished loading data for  Anguilla
# Finished loading data for  Antarctica
# Finished loading data for  Antigua and Barbuda
# Finished loading data for  Arctic Ocean
# Finished loading data for  Argentina
# Finished loading data for  Armenia
# Finished loading data for  Aruba
# Finished loading data for  Ashmore and Cartier Islands
# Finished loading data for  Atlantic Ocean
# Finished loading data for  Australia
# Finished loading data for  Austria
# Finished loading data for  Azerbaijan
# Finished loading data for  Bahamas, The
# Finished loading data for  Bahrain
# Finished loading data for  Baker Island
# Finished loading data for  Bangladesh
# Finished loading data for  Barbados
# Finished loading data for  Belarus
# Finished loading data for  Belgium
# Finished loading data for  Belize
# Finished loading data for  Benin
# Finished loading data for  Bermuda
# Finished loading data for  Bhutan
# Finished loading data for  Bolivia
# Finished loading data for  Bosnia and Herzegovina
# Finished loading data for  Botswana
# Finished loading data for  Bouvet Island
# Finished loading data for  Brazil
# Finished loading data for  British Indian Ocean Territory
# Finished loading data for  British Virgin Islands
# Finished loading data for  Brunei
# Finished loading data for  Bulgaria
# Finished loading data for  Burkina Faso
# Finished loading data for  Burma
# Finished loading data for  Burundi
# Finished loading data for  Cabo Verde
# Finished loading data for  Cambodia
# Finished loading data for  Cameroon
# Finished loading data for  Canada
# Finished loading data for  Cayman Islands
# Finished loading data for  Central African Republic
# Finished loading data for  Chad
# Finished loading data for  Chile
# Finished loading data for  Turkmenistan
# Finished loading data for  Turks and Caicos Islands
# Finished loading data for  Tuvalu
# Finished loading data for  Uganda
# Finished loading data for  Ukraine
# Finished loading data for  United Arab Emirates
# Finished loading data for  United Kingdom
# Finished loading data for  United States
# Finished loading data for  United States Pacific Island Wildlife Refuges
# Finished loading data for  Uruguay
# Finished loading data for  Uzbekistan
# Finished loading data for  Vanuatu
# Finished loading data for  Venezuela
# Finished loading data for  Vietnam
# Finished loading data for  Virgin Islands
# Finished loading data for  Wake Island
# Finished loading data for  Wallis and Futuna
# Finished loading data for  West Bank
# Finished loading data for  Western Sahara
# Finished loading data for  Yemen
# Finished loading data for  Zambia
# Finished loading data for  Zimbabwe
#
# **Finished downloading all text data!**

# %%
# Store in a Pickle dump if you like
# For good measure, serialize and store this data in a Python pickle object
# Allows for reading data directly after the initial web crawling, from the Jupyter notebook without repeating the web crawling steps.

import pickle
pickle.dump(text_data,open("text_data_CIA_Factobook.p", "wb"))
# Unpickle and read the data from local storage next time
text_data = pickle.load(open("text_data_CIA_Factobook.p", "rb"))

def convert_float(string):
    if string.isnumeric():
        return float(string)
    if string[0].isdigit():
        if ',' not in string and '.' in string:
            return float(string)
        if ',' not in string and '.' not in string:
            idx=string.find(' ')
            result = string[:idx]
            return float(result)
        idx1=string.find(',')
        idx2=string.find(' ')
        result = string[:idx1]+string[idx1+1:idx2]
        return float(result)
    else:
        return (-1)

# Using regular expression to extract the GDP/capita data from the text dump
# 'b' to catch 'billions', 't' to catch 'trillions'
# Notice the multiple error-handling checks placed in the code. 
import re

# Initialize dictionary for holding the data
GDP_PPP = {}
# Iterate over every country
for i in range(1,len(country_names)-1):
    country= country_names[i]
    txt=text_data[country]       
    pos = txt.find('GDP - per capita (PPP):')
    if pos!=-1: #If the wording/phrase is not present
        pos= pos+len('GDP - per capita (PPP):')
        string = txt[pos+1:pos+11]
        start = re.search('\$',string)
        end = re.search('\S',string)
        if (start!=None and end!=None): #If search fails somehow
            start=start.start()
            end=end.start()
            a=string[start+1:start+end-1]
            #print(a)
            a = convert_float(a)
            if (a!=-1.0): #If the float conversion fails somehow
                print("GDP/capita (PPP) of {}: {} dollars".format(country, a))
                # Insert the data in the dictionary
                GDP_PPP[country]=a
            else:
                print("**Could not find GDP/capita data!**")
        else:
            print("**Could not find GDP/capita data!**")
    else:
        print("**Could not find GDP/capita data!**")
print ("\nFinished finding all GDP/capita data")
# Out:
# GDP/capita (PPP) of  Afghanistan : 2000.0 dollars
# **Could not find GDP/capita data!**
# GDP/capita (PPP) of  Albania : 12500.0 dollars
# GDP/capita (PPP) of  Algeria : 15200.0 dollars
# GDP/capita (PPP) of  American Samoa : 11200.0 dollars
# GDP/capita (PPP) of  Andorra : 49900.0 dollars
# GDP/capita (PPP) of  Angola : 6800.0 dollars
# GDP/capita (PPP) of  Anguilla : 12200.0 dollars
# **Could not find GDP/capita data!**
# GDP/capita (PPP) of  Antigua and Barbuda : 26300.0 dollars
# **Could not find GDP/capita data!**
# GDP/capita (PPP) of  Argentina : 20900.0 dollars
# GDP/capita (PPP) of  Armenia : 9500.0 dollars
# GDP/capita (PPP) of  Aruba : 25300.0 dollars
# **Could not find GDP/capita data!**
# **Could not find GDP/capita data!**
# GDP/capita (PPP) of  
# GDP/capita (PPP) of  Yemen : 1300.0 dollars
# GDP/capita (PPP) of  Zambia : 4000.0 dollars
# GDP/capita (PPP) of  Zimbabwe : 2300.0 dollars
#
# Finished finding all GDP/capita data

# %%
# Using regular expression to extract the internet user percentage data from the text dump
# Initialize dictionary for holding the data
Internet_user = {}
# Iterate over every country
for i in range(1,len(country_names)-1):
    country= country_names[i]
    txt=text_data[country]       
    pos = txt.find('Internet users:')
    if pos!=-1: 
        pos= pos+len('Internet users: ')
        string = txt[pos:pos+50]
        #print(string)
        start=re.search('percent of population: ',string)
        end = re.search('%',string)
        if (start!=None and end!=None):
            start=start.end()
            end=end.start()
            a=string[start:end]
            if a[-1].isdigit():
                a = float(a)
                print("Internet users % of {}: {}".format(country, a))
                # Insert the data in the dictionary
                Internet_user[country]=a
            else:
                print("**Could not find Internet users data!**")
        else:
            print("**Could not find Internet users data!**")
    else:
        print("**Could not find Internet users data!**")

print ("\nFinished finding all Internet users data")
# Out:
# Internet users % of  Afghanistan : 10.6
# **Could not find Internet users data!**
# Internet users % of  Albania : 66.4
# Internet users % of  Algeria : 42.9
# Internet users % of  American Samoa : 31.3
# Internet users % of  Andorra : 97.9
# Internet users % of  Angola : 13.0
# Internet users % of  Anguilla : 81.6
# Internet users % of  Antarctica : 100.0
# Internet users % of  Antigua and Barbuda : 65.2
# **Could not find Internet users data!**
# Internet users % of  Argentina : 70.2
# Internet users % of  Armenia : 62.0
# Internet users % of  Aruba : 93.5
# **Could not find Internet users data!**
# **Could not find Internet users data!**
# Internet users % of  Australia : 88.2
# Internet users % of  Austria : 84.3
# Internet users % of  Azerbaijan : 78.2
# Internet users % of  Bahamas, The : 80.0
# Internet users % of  Bahrain : 98.0
# **Could not find Internet users data!**
# Internet users % of  Bangladesh : 18.2
# Internet users % of  Barbados : 79.5
# Internet users % of  Belarus : 71.1
# Internet users % of  Belgium : 86.5
# Internet users % of  Belize : 44.6
# Internet users % of  Benin : 12.0
# Internet users % of  Bermuda : 98.0
# Internet users % of  Bhutan : 41.8
# Internet users % of  Bolivia : 39.7
# Internet users % of  Bosnia and Herzegovina : 69.3
# Internet users % of  Botswana : 39.4
# **Could not find Internet users data!**
# Internet users % of  Brazil : 59.7
# **Could not find Internet users data!**
# Internet users % of  British Virgin Islands : 43.6
# Internet users % of  Brunei : 71.2
# Internet users % of  Bulgaria : 59.8
# Internet users % of  Burkina Faso : 14.0
# Internet users % of  Burma : 25.1
# Internet users % of  Burundi : 5.2
# Internet users % of  Cabo Verde : 48.2
# Internet users % of  Cambodia : 25.6
# Internet users % of  Cameroon : 25.0
# Internet users % of  Canada : 89.8
# Internet users % of  Cayman Islands : 79.0
# Internet users % of  Central African Republic : 4.6
# Internet users % of  Chad : 5.0
# Internet users % of  Chile : 66.0
# Internet users % of  China : 53.2
# Internet users % of  Christmas Island : 35.8
# **Could not find Internet users data!**
# **Could not find Internet users data!**
# Internet users % of  Colombia : 58.1
# Internet users % of  Comoros : 7.9
# Internet users % of  Congo, Democratic Republic of the : 3.8
# Internet users % of  Congo, Republic of the : 7.6
# Internet users % of  Cook Islands : 54.0
# **Could not find Internet users data!**
# Internet users % of  Costa Rica : 66.0
# Internet users % of  Cote d'Ivoire : 26.5
# Internet users % of  Croatia : 72.7
# Internet users % of  Cuba : 38.8
# Internet users % of  Curacao : 93.9
# Internet users % of  Cyprus : 75.9
# Internet users % of  Czechia : 76.5
# Internet users % of  Denmark : 97.0
# **Could not find Internet users data!**
# Internet users % of  Djibouti : 13.1
# Internet users % of  Dominica : 67.0
# Internet users % of  Dominican Republic : 61.3
# Internet users % of  Ecuador : 54.1
# Internet users % of  Egypt : 39.2
# Internet users % of  El Salvador : 29.0
# Internet users % of  Equatorial Guinea : 23.8
# Internet users % of  Eritrea : 1.2
# Internet users % of  Estonia : 87.2
# Internet users % of  Eswatini : 28.6
# Internet users % of  Ethiopia : 15.4
# Internet users % of  Falkland Islands (Islas Malvinas) : 98.3
# Internet users % of  Faroe Islands : 95.1
# Internet users % of  Fiji : 46.5
# Internet users % of  Finland : 87.7
# Internet users % of  France : 85.6
# Internet users % of  French Polynesia : 68.4
# **Could not find Internet users data!**
# Internet users % of  Gabon : 48.1
# Internet users % of  Gambia, The : 18.5
# **Could not find Internet users data!**
# Internet users % of  Georgia : 50.0
# Internet users % of  Germany : 89.6
# Internet users % of  Ghana : 34.7
# Internet users % of  Gibraltar : 94.4
# Internet users % of  Greece : 69.1
# Internet users % of  Greenland : 68.5
# Internet users % of  Grenada : 55.9
# Internet users % of  Guam : 77.0
# Internet users % of  Guatemala : 34.5
# Internet users % of  Guernsey : 83.3
# Internet users % of  Guinea : 9.8
# Internet users % of  Guinea-Bissau : 3.8
# Internet users % of  Guyana : 35.7
# Internet users % of  Haiti : 12.2
# **Could not find Internet users data!**
# **Could not find Internet users data!**
# Internet users % of  Honduras : 30.0
# Internet users % of  Hong Kong : 85.0
# **Could not find Internet users data!**
# Internet users % of  Hungary : 79.3
# Internet users % of  Iceland : 98.2
# Internet users % of  India : 29.5
# **Could not find Internet users data!**
# Internet users % of  Indonesia : 25.4
# Internet users % of  Iran : 44.1
# Internet users % of  Iraq : 21.2
# Internet users % of  Ireland : 82.2
# **Could not find Internet users data!**
# Internet users % of  Israel : 79.8
# Internet users % of  Italy : 61.3
# Internet users % of  Jamaica : 45.0
# **Could not find Internet users data!**
# Internet users % of  Japan : 92.0
# **Could not find Internet users data!**
# Internet users % of  Jersey : 59.6
# **Could not find Internet users data!**
# Internet users % of  Jordan : 62.3
# Internet users % of  Kazakhstan : 76.8
# Internet users % of  Kenya : 26.0
# **Could not find Internet users data!**
# Internet users % of  Kiribati : 13.7
# **Could not find Internet users data!**
# Internet users % of  Korea, South : 89.9
# **Could not find Internet users data!**
# Internet users % of  Kuwait : 78.4
# Internet users % of  Kyrgyzstan : 34.5
# Internet users % of  Laos : 18.2
# Internet users % of  Latvia : 79.9
# Internet users % of  Lebanon : 76.1
# Internet users % of  Lesotho : 27.4
# Internet users % of  Liberia : 7.3
# Internet users % of  Libya : 20.3
# Internet users % of  Liechtenstein : 98.1
# Internet users % of  Lithuania : 74.4
# Internet users % of  Luxembourg : 97.5
# Internet users % of  Macau : 77.6
# **Could not find Internet users data!**
# Internet users % of  Madagascar : 4.7
# Internet users % of  Malawi : 9.6
# Internet users % of  Malaysia : 78.8
# Internet users % of  Maldives : 59.1
# Internet users % of  Mali : 11.1
# Internet users % of  Malta : 77.3
# Internet users % of  Marshall Islands : 29.8
# Internet users % of  Mauritania : 18.0
# Internet users % of  Mauritius : 53.2
# Internet users % of  Mexico : 59.5
# Internet users % of  Micronesia, Federated States of : 31.5
# **Could not find Internet users data!**
# Internet users % of  Moldova : 71.0
# Internet users % of  Monaco : 95.2
# Internet users % of  Mongolia : 22.3
# Internet users % of  Montenegro : 69.9
# Internet users % of  Montserrat : 54.6
# Internet users % of  Morocco : 58.3
# Internet users % of  Mozambique : 17.5
# Internet users % of  Namibia : 31.0
# Internet users % of  Nauru : 53.5
# **Could not find Internet users data!**
# Internet users % of  Nepal : 19.7
# Internet users % of  Netherlands : 90.4
# Internet users % of  New Caledonia : 74.0
# Internet users % of  New Zealand : 88.5
# Internet users % of  Nicaragua : 24.6
# Internet users % of  Niger : 4.3
# Internet users % of  Nigeria : 25.7
# Internet users % of  Niue : 91.6
# Internet users % of  Norfolk Island : 34.6
# Internet users % of  Northern Mariana Islands : 30.6
# Internet users % of  Norway : 97.3
# Internet users % of  Oman : 69.8
# **Could not find Internet users data!**
# Internet users % of  Pakistan : 15.5
# Internet users % of  Palau : 36.0
# **Could not find Internet users data!**
# Internet users % of  Panama : 54.0
# Internet users % of  Papua New Guinea : 9.6
# **Could not find Internet users data!**
# Internet users % of  Paraguay : 51.3
# Internet users % of  Peru : 45.5
# Internet users % of  Philippines : 55.5
# Internet users % of  Pitcairn Islands : 100.0
# Internet users % of  Poland : 73.3
# Internet users % of  Portugal : 70.4
# Internet users % of  Puerto Rico : 80.3
# Internet users % of  Qatar : 94.3
# Internet users % of  Romania : 59.5
# Internet users % of  Russia : 76.4
# Internet users % of  Rwanda : 29.8
# **Could not find Internet users data!**
# Internet users % of  Saint Helena, Ascension, and Tristan da Cunha : 23.1
# Internet users % of  Saint Kitts and Nevis : 75.7
# Internet users % of  Saint Lucia : 52.4
# Internet users % of  Saint Martin : 3.5
# Internet users % of  Saint Pierre and Miquelon : 79.5
# Internet users % of  Saint Vincent and the Grenadines : 51.8
# Internet users % of  Samoa : 29.4
# Internet users % of  San Marino : 52.6
# Internet users % of  Sao Tome and Principe : 25.8
# Internet users % of  Saudi Arabia : 73.8
# Internet users % of  Senegal : 25.7
# Internet users % of  Serbia : 67.1
# Internet users % of  Seychelles : 56.5
# Internet users % of  Sierra Leone : 11.8
# Internet users % of  Singapore : 81.0
# **Could not find Internet users data!**
# Internet users % of  Slovakia : 80.5
# Internet users % of  Slovenia : 75.5
# Internet users % of  Solomon Islands : 11.0
# Internet users % of  Somalia : 1.9
# Internet users % of  South Africa : 54.0
# **Could not find Internet users data!**
# **Could not find Internet users data!**
# **Could not find Internet users data!**
# Internet users % of  Spain : 80.6
# **Could not find Internet users data!**
# Internet users % of  Sri Lanka : 32.1
# Internet users % of  Sudan : 28.0
# Internet users % of  Suriname : 45.4
# **Could not find Internet users data!**
# Internet users % of  Sweden : 91.5
# Internet users % of  Switzerland : 89.4
# Internet users % of  Syria : 31.9
# Internet users % of  Taiwan : 88.0
# Internet users % of  Tajikistan : 20.5
# Internet users % of  Tanzania : 13.0
# Internet users % of  Thailand : 47.5
# Internet users % of  Timor-Leste : 25.2
# Internet users % of  Togo : 11.3
# Internet users % of  Tokelau : 60.2
# Internet users % of  Tonga : 40.0
# Internet users % of  Trinidad and Tobago : 69.2
# Internet users % of  Tunisia : 50.9
# Internet users % of  Turkey : 58.3
# Internet users % of  Turkmenistan : 18.0
# **Could not find Internet users data!**
# Internet users % of  Tuvalu : 46.0
# Internet users % of  Uganda : 45.9
# Internet users % of  Ukraine : 52.5
# Internet users % of  United Arab Emirates : 90.6
# Internet users % of  United Kingdom : 94.8
# Internet users % of  United States : 76.2
# **Could not find Internet users data!**
# Internet users % of  Uruguay : 66.4
# Internet users % of  Uzbekistan : 46.8
# Internet users % of  Vanuatu : 24.0
# Internet users % of  Venezuela : 60.0
# Internet users % of  Vietnam : 52.7
# Internet users % of  Virgin Islands : 54.8
# **Could not find Internet users data!**
# Internet users % of  Wallis and Futuna : 22.1
# **Could not find Internet users data!**
# **Could not find Internet users data!**
# Internet users % of  Yemen : 24.6
# Internet users % of  Zambia : 25.5
# Internet users % of  Zimbabwe : 23.1
#
# Finished finding all Internet users data

# %%
Internet_user
# Out:
# {' Afghanistan ': 10.6,
#  ' Albania ': 66.4,
#  ' Algeria ': 42.9,
#  ' American Samoa ': 31.3,
#  ' Andorra ': 97.9,
#  ' Angola ': 13.0,
#  ' Anguilla ': 81.6,
#  ' Antarctica ': 100.0,
#  ' Antigua and Barbuda ': 65.2,
#  ' Argentina ': 70.2,
#  ' Armenia ': 62.0,
#  ' Aruba ': 93.5,
#  ' Australia ': 88.2,
#  ' Austria ': 84.3,
#  ' Azerbaijan ': 78.2,
#  ' Bahamas, The ': 80.0,
#  ' Bahrain ': 98.0,
#  ' Bangladesh ': 18.2,
#  ' Barbados ': 79.5,
#  ' Belarus ': 71.1,
#  ' Belgium ': 86.5,
#  ' Belize ': 44.6,
#  ' Benin ': 12.0,
#  ' Bermuda ': 98.0,
#  ' Bhutan ': 41.8,
#  ' Bolivia ': 39.7,
#  ' Bosnia and Herzegovina ': 69.3,
#  ' Botswana ': 39.4,
#  ' Brazil ': 59.7,
#  ' British Virgin Islands ': 43.6,
#  ' Brunei ': 71.2,
#  ' Bulgaria ': 59.8,
#  ' Burkina Faso ': 14.0,
#  ' Burma ': 25.1,
#  ' Burundi ': 5.2,
#  ' Cabo Verde ': 48.2,
#  ' Cambodia ': 25.6,
#  ' Cameroon ': 25.0,
#  ' Canada ': 89.8,
#  ' Cayman Islands ': 79.0,
#  ' Central African Republic ': 4.6,
#  ' Chad ': 5.0,
#  ' Chile ': 66.0,
#  ' China ': 53.2,
#  ' Christmas Island ': 35.8,
#  ' Colombia ': 58.1,
#  ' Comoros ': 7.9,
#  ' Congo, Democratic Republic of the ': 3.8,
#  ' Congo, Republic of the ': 7.6,
#  ' Cook Islands ': 54.0,
#  ' Costa Rica ': 66.0,
#  " Cote d'Ivoire ": 26.5,
#  ' Croatia ': 72.7,
#  ' Cuba ': 38.8,
#  ' Curacao ': 93.9,
#  ' Cyprus ': 75.9,
#  ' Czechia ': 76.5,
#  ' Denmark ': 97.0,
#  ' Djibouti ': 13.1,
#  ' Dominica ': 67.0,
#  ' Dominican Republic ': 61.3,
#  ' Ecuador ': 54.1,
#  ' Egypt ': 39.2,
#  ' El Salvador ': 29.0,
#  ' Equatorial Guinea ': 23.8,
#  ' Eritrea ': 1.2,
#  ' Estonia ': 87.2,
#  ' Eswatini ': 28.6,
#  ' Ethiopia ': 15.4,
#  ' Falkland Islands (Islas Malvinas) ': 98.3,
#  ' Faroe Islands ': 95.1,
#  ' Fiji ': 46.5,
#  ' Finland ': 87.7,
#  ' France ': 85.6,
#  ' French Polynesia ': 68.4,
#  ' Gabon ': 48.1,
#  ' Gambia, The ': 18.5,
#  ' Georgia ': 50.0,
#  ' Germany ': 89.6,
#  ' Ghana ': 34.7,
#  ' Gibraltar ': 94.4,
#  ' Greece ': 69.1,
#  ' Greenland ': 68.5,
#  ' Grenada ': 55.9,
#  ' Guam ': 77.0,
#  ' Guatemala ': 34.5,
#  ' Guernsey ': 83.3,
#  ' Guinea ': 9.8,
#  ' Guinea-Bissau ': 3.8,
#  ' Guyana ': 35.7,
#  ' Haiti ': 12.2,
#  ' Honduras ': 30.0,
#  ' Hong Kong ': 85.0,
#  ' Hungary ': 79.3,
#  ' Iceland ': 98.2,
#  ' India ': 29.5,
#  ' Indonesia ': 25.4,
#  ' Iran ': 44.1,
#  ' Iraq ': 21.2,
#  ' Ireland ': 82.2,
#  ' Israel ': 79.8,
#  ' Italy ': 61.3,
#  ' Jamaica ': 45.0,
#  ' Japan ': 92.0,
#  ' Jersey ': 59.6,
#  ' Jordan ': 62.3,
#  ' Kazakhstan ': 76.8,
#  ' Kenya ': 26.0,
#  ' Kiribati ': 13.7,
#  ' Korea, South ': 89.9,
#  ' Kuwait ': 78.4,
#  ' Kyrgyzstan ': 34.5,
#  ' Laos ': 18.2,
#  ' Latvia ': 79.9,
#  ' Lebanon ': 76.1,
#  ' Lesotho ': 27.4,
#  ' Liberia ': 7.3,
#  ' Libya ': 20.3,
#  ' Liechtenstein ': 98.1,
#  ' Lithuania ': 74.4,
#  ' Luxembourg ': 97.5,
#  ' Macau ': 77.6,
#  ' Madagascar ': 4.7,
#  ' Malawi ': 9.6,
#  ' Malaysia ': 78.8,
#  ' Maldives ': 59.1,
#  ' Mali ': 11.1,
#  ' Malta ': 77.3,
#  ' Marshall Islands ': 29.8,
#  ' Mauritania ': 18.0,
#  ' Mauritius ': 53.2,
#  ' Mexico ': 59.5,
#  ' Micronesia, Federated States of ': 31.5,
#  ' Moldova ': 71.0,
#  ' Monaco ': 95.2,
#  ' Mongolia ': 22.3,
#  ' Montenegro ': 69.9,
#  ' Montserrat ': 54.6,
#  ' Morocco ': 58.3,
#  ' Mozambique ': 17.5,
#  ' Namibia ': 31.0,
#  ' Nauru ': 53.5,
#  ' Nepal ': 19.7,
#  ' Netherlands ': 90.4,
#  ' New Caledonia ': 74.0,
#  ' New Zealand ': 88.5,
#  ' Nicaragua ': 24.6,
#  ' Niger ': 4.3,
#  ' Nigeria ': 25.7,
#  ' Niue ': 91.6,
#  ' Norfolk Island ': 34.6,
#  ' Northern Mariana Islands ': 30.6,
#  ' Norway ': 97.3,
#  ' Oman ': 69.8,
#  ' Pakistan ': 15.5,
#  ' Palau ': 36.0,
#  ' Panama ': 54.0,
#  ' Papua New Guinea ': 9.6,
#  ' Paraguay ': 51.3,
#  ' Peru ': 45.5,
#  ' Philippines ': 55.5,
#  ' Pitcairn Islands ': 100.0,
#  ' Poland ': 73.3,
#  ' Portugal ': 70.4,
#  ' Puerto Rico ': 80.3,
#  ' Qatar ': 94.3,
#  ' Romania ': 59.5,
#  ' Russia ': 76.4,
#  ' Rwanda ': 29.8,
#  ' Saint Helena, Ascension, and Tristan da Cunha ': 23.1,
#  ' Saint Kitts and Nevis ': 75.7,
#  ' Saint Lucia ': 52.4,
#  ' Saint Martin ': 3.5,
#  ' Saint Pierre and Miquelon ': 79.5,
#  ' Saint Vincent and the Grenadines ': 51.8,
#  ' Samoa ': 29.4,
#  ' San Marino ': 52.6,
#  ' Sao Tome and Principe ': 25.8,
#  ' Saudi Arabia ': 73.8,
#  ' Senegal ': 25.7,
#  ' Serbia ': 67.1,
#  ' Seychelles ': 56.5,
#  ' Sierra Leone ': 11.8,
#  ' Singapore ': 81.0,
#  ' Slovakia ': 80.5,
#  ' Slovenia ': 75.5,
#  ' Solomon Islands ': 11.0,
#  ' Somalia ': 1.9,
#  ' South Africa ': 54.0,
#  ' Spain ': 80.6,
#  ' Sri Lanka ': 32.1,
#  ' Sudan ': 28.0,
#  ' Suriname ': 45.4,
#  ' Sweden ': 91.5,
#  ' Switzerland ': 89.4,
#  ' Syria ': 31.9,
#  ' Taiwan ': 88.0,
#  ' Tajikistan ': 20.5,
#  ' Tanzania ': 13.0,
#  ' Thailand ': 47.5,
#  ' Timor-Leste ': 25.2,
#  ' Togo ': 11.3,
#  ' Tokelau ': 60.2,
#  ' Tonga ': 40.0,
#  ' Trinidad and Tobago ': 69.2,
#  ' Tunisia ': 50.9,
#  ' Turkey ': 58.3,
#  ' Turkmenistan ': 18.0,
#  ' Tuvalu ': 46.0,
#  ' Uganda ': 45.9,
#  ' Ukraine ': 52.5,
#  ' United Arab Emirates ': 90.6,
#  ' United Kingdom ': 94.8,
#  ' United States ': 76.2,
#  ' Uruguay ': 66.4,
#  ' Uzbekistan ': 46.8,
#  ' Vanuatu ': 24.0,
#  ' Venezuela ': 60.0,
#  ' Vietnam ': 52.7,
#  ' Virgin Islands ': 54.8,
#  ' Wallis and Futuna ': 22.1,
#  ' Yemen ': 24.6,
#  ' Zambia ': 25.5,
#  ' Zimbabwe ': 23.1}

# %%
GDP_PPP
# Out:
# {' Afghanistan ': 2000.0,
#  ' Albania ': 12500.0,
#  ' Algeria ': 15200.0,
#  ' American Samoa ': 11200.0,
#  ' Andorra ': 49900.0,
#  ' Angola ': 6800.0,
#  ' Anguilla ': 12200.0,
#  ' Antigua and Barbuda ': 26300.0,
#  ' Argentina ': 20900.0,
#  ' Armenia ': 9500.0,
#  ' Aruba ': 25300.0,
#  ' Australia ': 50300.0,
#  ' Austria ': 49900.0,
#  ' Azerbaijan ': 17500.0,
#  ' Bahamas, The ': 31200.0,
#  ' Bahrain ': 48500.0,
#  ' Bangladesh ': 4200.0,
#  ' Barbados ': 18700.0,
#  ' Belarus ': 18900.0,
#  ' Belgium ': 46600.0,
#  ' Belize ': 8300.0,
#  ' Benin ': 2300.0,
#  ' Bermuda ': 99400.0,
#  ' Bhutan ': 8700.0,
#  ' Bolivia ': 7500.0,
#  ' Bosnia and Herzegovina ': 12700.0,
#  ' Botswana ': 17800.0,
#  ' Brazil ': 15600.0,
#  ' British Virgin Islands ': 34200.0,
#  ' Brunei ': 78200.0,
#  ' Bulgaria ': 21700.0,
#  ' Burkina Faso ': 1900.0,
#  ' Burma ': 6200.0,
#  ' Burundi ': 700.0,
#  ' Cabo Verde ': 6900.0,
#  ' Cambodia ': 4000.0,
#  ' Cameroon ': 3700.0,
#  ' Canada ': 48300.0,
#  ' Cayman Islands ': 43800.0,
#  ' Central African Republic ': 700.0,
#  ' Chad ': 2300.0,
#  ' Chile ': 24500.0,
#  ' China ': 16700.0,
#  ' Colombia ': 14500.0,
#  ' Comoros ': 1600.0,
#  ' Congo, Democratic Republic of the ': 800.0,
#  ' Congo, Republic of the ': 6600.0,
#  ' Cook Islands ': 16700.0,
#  ' Costa Rica ': 16900.0,
#  " Cote d'Ivoire ": 3900.0,
#  ' Croatia ': 24400.0,
#  ' Cuba ': 12300.0,
#  ' Curacao ': 15000.0,
#  ' Cyprus ': 37000.0,
#  ' Czechia ': 35500.0,
#  ' Denmark ': 49900.0,
#  ' Djibouti ': 3600.0,
#  ' Dominica ': 11100.0,
#  ' Dominican Republic ': 16900.0,
#  ' Ecuador ': 11500.0,
#  ' Egypt ': 12700.0,
#  ' El Salvador ': 8900.0,
#  ' Equatorial Guinea ': 36000.0,
#  ' Eritrea ': 1600.0,
#  ' Estonia ': 31800.0,
#  ' Eswatini ': 9900.0,
#  ' Ethiopia ': 2200.0,
#  ' Falkland Islands (Islas Malvinas) ': 70800.0,
#  ' Faroe Islands ': 40000.0,
#  ' Fiji ': 9800.0,
#  ' Finland ': 44300.0,
#  ' France ': 43800.0,
#  ' French Polynesia ': 17000.0,
#  ' Gabon ': 19200.0,
#  ' Gambia, The ': 1700.0,
#  ' Georgia ': 10700.0,
#  ' Germany ': 50400.0,
#  ' Ghana ': 4700.0,
#  ' Gibraltar ': 61700.0,
#  ' Greece ': 27700.0,
#  ' Greenland ': 41800.0,
#  ' Grenada ': 14900.0,
#  ' Guam ': 35600.0,
#  ' Guatemala ': 8100.0,
#  ' Guernsey ': 52500.0,
#  ' Guinea ': 2000.0,
#  ' Guinea-Bissau ': 1800.0,
#  ' Guyana ': 8200.0,
#  ' Haiti ': 1800.0,
#  ' Honduras ': 5600.0,
#  ' Hong Kong ': 61400.0,
#  ' Hungary ': 29500.0,
#  ' Iceland ': 51800.0,
#  ' India ': 7200.0,
#  ' Indonesia ': 12400.0,
#  ' Iran ': 20200.0,
#  ' Iraq ': 17000.0,
#  ' Ireland ': 75500.0,
#  ' Isle of Man ': 84600.0,
#  ' Israel ': 36300.0,
#  ' Italy ': 38100.0,
#  ' Jamaica ': 9200.0,
#  ' Japan ': 42800.0,
#  ' Jersey ': 56600.0,
#  ' Jordan ': 12500.0,
#  ' Kazakhstan ': 26300.0,
#  ' Kenya ': 3500.0,
#  ' Kiribati ': 2000.0,
#  ' Korea, North ': 1700.0,
#  ' Korea, South ': 39400.0,
#  ' Kosovo ': 10500.0,
#  ' Kuwait ': 66200.0,
#  ' Kyrgyzstan ': 3700.0,
#  ' Laos ': 7400.0,
#  ' Latvia ': 27600.0,
#  ' Lebanon ': 19400.0,
#  ' Lesotho ': 3600.0,
#  ' Liberia ': 1400.0,
#  ' Libya ': 10000.0,
#  ' Liechtenstein ': 139100.0,
#  ' Lithuania ': 32300.0,
#  ' Luxembourg ': 106300.0,
#  ' Macau ': 111600.0,
#  ' Macedonia ': 14900.0,
#  ' Madagascar ': 1600.0,
#  ' Malawi ': 1200.0,
#  ' Malaysia ': 29000.0,
#  ' Maldives ': 19100.0,
#  ' Mali ': 2200.0,
#  ' Malta ': 42000.0,
#  ' Marshall Islands ': 3400.0,
#  ' Mauritania ': 4400.0,
#  ' Mauritius ': 21600.0,
#  ' Mexico ': 19900.0,
#  ' Micronesia, Federated States of ': 3400.0,
#  ' Moldova ': 5700.0,
#  ' Monaco ': 115700.0,
#  ' Mongolia ': 13000.0,
#  ' Montenegro ': 17700.0,
#  ' Montserrat ': 34000.0,
#  ' Morocco ': 8600.0,
#  ' Mozambique ': 1200.0,
#  ' Namibia ': 11300.0,
#  ' Nauru ': 12200.0,
#  ' Nepal ': 2700.0,
#  ' Netherlands ': 53600.0,
#  ' New Caledonia ': 31100.0,
#  ' New Zealand ': 38900.0,
#  ' Nicaragua ': 5800.0,
#  ' Niger ': 1200.0,
#  ' Nigeria ': 5900.0,
#  ' Niue ': 5800.0,
#  ' Northern Mariana Islands ': 24500.0,
#  ' Norway ': 71800.0,
#  ' Oman ': 45200.0,
#  ' Pakistan ': 5400.0,
#  ' Palau ': 16200.0,
#  ' Panama ': 25400.0,
#  ' Papua New Guinea ': 3700.0,
#  ' Paraguay ': 9800.0,
#  ' Peru ': 13300.0,
#  ' Philippines ': 8300.0,
#  ' Poland ': 29500.0,
#  ' Portugal ': 30400.0,
#  ' Puerto Rico ': 37300.0,
#  ' Qatar ': 124500.0,
#  ' Romania ': 24500.0,
#  ' Russia ': 27800.0,
#  ' Rwanda ': 2100.0,
#  ' Saint Helena, Ascension, and Tristan da Cunha ': 7800.0,
#  ' Saint Kitts and Nevis ': 26800.0,
#  ' Saint Lucia ': 14400.0,
#  ' Saint Martin ': 19300.0,
#  ' Saint Pierre and Miquelon ': 46200.0,
#  ' Saint Vincent and the Grenadines ': 11500.0,
#  ' Samoa ': 5700.0,
#  ' San Marino ': 58600.0,
#  ' Sao Tome and Principe ': 3200.0,
#  ' Saudi Arabia ': 54800.0,
#  ' Senegal ': 2700.0,
#  ' Serbia ': 15000.0,
#  ' Seychelles ': 28900.0,
#  ' Sierra Leone ': 1600.0,
#  ' Singapore ': 93900.0,
#  ' Sint Maarten ': 66800.0,
#  ' Slovakia ': 33000.0,
#  ' Slovenia ': 34400.0,
#  ' Solomon Islands ': 2200.0,
#  ' South Africa ': 13500.0,
#  ' South Sudan ': 1500.0,
#  ' Spain ': 38300.0,
#  ' Sri Lanka ': 12800.0,
#  ' Sudan ': 4600.0,
#  ' Suriname ': 14600.0,
#  ' Sweden ': 51500.0,
#  ' Switzerland ': 61400.0,
#  ' Syria ': 2900.0,
#  ' Taiwan ': 50300.0,
#  ' Tajikistan ': 3200.0,
#  ' Tanzania ': 3200.0,
#  ' Thailand ': 17900.0,
#  ' Timor-Leste ': 5400.0,
#  ' Togo ': 1700.0,
#  ' Tokelau ': 1000.0,
#  ' Tonga ': 5600.0,
#  ' Trinidad and Tobago ': 31400.0,
#  ' Tunisia ': 11800.0,
#  ' Turkey ': 26900.0,
#  ' Turkmenistan ': 18100.0,
#  ' Turks and Caicos Islands ': 29100.0,
#  ' Tuvalu ': 3800.0,
#  ' Uganda ': 2400.0,
#  ' Ukraine ': 8700.0,
#  ' United Arab Emirates ': 67700.0,
#  ' United Kingdom ': 44100.0,
#  ' United States ': 59500.0,
#  ' Uruguay ': 22400.0,
#  ' Uzbekistan ': 6900.0,
#  ' Vanuatu ': 2700.0,
#  ' Venezuela ': 12100.0,
#  ' Vietnam ': 6900.0,
#  ' Virgin Islands ': 37000.0,
#  ' Wallis and Futuna ': 3800.0,
#  ' West Bank ': 4300.0,
#  ' Western Sahara ': 2500.0,
#  ' Yemen ': 1300.0,
#  ' Zambia ': 4000.0,
#  ' Zimbabwe ': 2300.0}

# %%
# Saving into CSV
import csv

with open('InternetUsers-GDPPerCapita.csv', mode='w') as csv_file:
    fieldnames = ['Country', 'Internet Users %', 'GDP/Capita']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for key, value in Internet_user.items():
        try:
            writer.writerow({'Country': key.strip(), 'Internet Users %': value, 'GDP/Capita': GDP_PPP[key]})
        except:
            continue
